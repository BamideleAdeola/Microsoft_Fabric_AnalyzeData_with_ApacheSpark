# %% [markdown]
# # Sales Report - Test
# - This shows a sample Spark pool in Microsoft Fabric
# - All data are for sample demo not a real datasets
# - Reference: Microsoft Learn

# %%
from pyspark.sql.types import *

orderSch = StructType([
    StructField("SalesOrderNumber", StringType()),
    StructField("SalesOrderLineNumber", IntegerType()),
    StructField("OrderDate", DateType()),
    StructField("CustomerName", StringType()),
    StructField("EmailAddress", StringType()),
    StructField("Item", StringType()),
    StructField("Quantity", IntegerType()),
    StructField("UnitPrice", FloatType()),
    StructField("TaxAmount", FloatType())
])

# df = spark.read.format("csv").schema(orderSchema).load("Files/sales/*.csv")

df = spark.read.format("csv").schema(orderSch).load("Files/sales.csv")
display(df)
# Out:
# StatementMeta(, 3264d30f-260d-4c7a-8fcd-7588746c2ae7, 3, Finished, Available)
# SynapseWidget(Synapse.DataFrame, d0bc24a6-9579-48f9-9f38-756e0fa47958)

# %%
# Retrieve first 5 rows of the dataframe
df.head()
# Out:
# StatementMeta(, 3264d30f-260d-4c7a-8fcd-7588746c2ae7, 4, Finished, Available)
# Row(SalesOrderNumber='SalesOrderNumber', SalesOrderLineNumber=None, OrderDate=None, CustomerName='CustomerName', EmailAddress='EmailAddress', Item='Item', Quantity=None, UnitPrice=None, TaxAmount=None)

# %%
# Display the dataframe
display(df)
# Out:
# StatementMeta(, 3264d30f-260d-4c7a-8fcd-7588746c2ae7, 5, Finished, Available)
# SynapseWidget(Synapse.DataFrame, 5a1ee14f-aade-4709-9099-25ff6c081035)
